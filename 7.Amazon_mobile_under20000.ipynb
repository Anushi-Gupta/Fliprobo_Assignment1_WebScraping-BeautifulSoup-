# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
proxies = {
  'http': 'http://134.119.205.253:8080',
  'https': 'http://134.119.205.253:8080',
}

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

# %%
r = requests.get('https://www.amazon.in/s?k=smartphones&i=electronics&rh=n%3A976419031%2Cp_36%3A-2000000&dc&page=1', headers=headers)#, proxies=proxies)
content = r.content

# %%
r
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(content, 'html.parser')
pages = soup.find('li', {'aria-disabled': 'true'})

# %%
Name=[]
price=[]
rating=[]
image=[]

# %%
for p in range(1,25):
    r1 = requests.get('https://www.amazon.in/s?k=smartphones&i=electronics&rh=n%3A976419031%2Cp_36%3A-2000000&dc&page=' + str(p), headers=headers)#, proxies=proxies)
    content1 = r.content

    soup1 = BeautifulSoup(content, 'html.parser')
    
    get_title=soup.find_all('a',attrs={'class':'a-link-normal a-text-normal'})
    for i in get_title:
        Name.append(i.text.replace('\n',''))

# %%
Name
# Out:
# ['Samsung Galaxy M21 (Raven Black, 6GB RAM, 128GB Storage)',
#  'Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)',
#  'Samsung Galaxy M21 (Midnight Blue, 4GB RAM, 64GB Storage)',
#  'Samsung Galaxy M01 Core (Black, 2GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Redmi 9A (Nature Green, 2GB Ram, 32GB Storage)',
#  'Samsung Galaxy M01 (Black, 3GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Panasonic Eluga i7 (2GB RAM, 16GB Storage, Finger Print Sensor, 4000mAh Battery) (Black)',
#  'Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Storage) - 48MP Quad Camera & Full HD+ Display',
#  'Samsung Galaxy M21 (Raven Black, 4GB RAM, 64GB Storage)',
#  'Redmi 9 (Carbon Black, 4GB RAM, 64GB Storage)',
#  'Samsung Galaxy M01 (Blue, 3GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Samsung Galaxy M01 Core (Black, 1GB RAM, 16GB Storage) with No Cost EMI/Additional Exchange Offers',
# ...

# %%
for p in range(1,25):
    r1 = requests.get('https://www.amazon.in/s?k=smartphones&i=electronics&rh=n%3A976419031%2Cp_36%3A-2000000&dc&page=' + str(p), headers=headers)#, proxies=proxies)
    content1 = r.content

    soup1 = BeautifulSoup(content, 'html.parser')
    
    get_price=soup.find_all('span',attrs={'class':'a-price-whole'})
    for i in get_price:
        price.append(i.text.replace('\n',''))

# %%
price
# Out:
# ['15,999',
#  '8,999',
#  '13,999',
#  '5,999',
#  '6,999',
#  '7,499',
#  '5,000',
#  '11,999',
#  '13,999',
#  '8,999',
#  '7,499',
#  '4,999',
#  '12,999',
#  '5,299',
#  '6,599',
#  '5,999',
#  '5,399',
#  '14,999',
#  '5,299',
#  '8,990',
#  '16,499',
#  '11,990',
#  '9,990',
#  '5,399',
#  '5,299',
#  '15,999',
#  '8,999',
#  '13,999',
#  '5,999',
#  '6,999',
#  '7,499',
#  '5,000',
#  '11,999',
#  '13,999',
#  '8,999',
#  '7,499',
#  '4,999',
#  '12,999',
#  '5,299',
#  '6,599',
#  '5,999',
#  '5,399',
#  '14,999',
#  '5,299',
#  '8,990',
#  '16,499',
#  '11,990',
#  '9,990',
#  '5,399',
#  '5,299',
#  '15,999',
#  '8,999',
#  '13,999',
#  '5,999',
#  '6,999',
#  '7,499',
#  '5,000',
#  '11,999',
#  '13,999',
#  '8,999',
#  '7,499',
#  '4,999',
#  '12,999',
#  '5,299',
#  '6,599',
#  '5,999',
#  '5,399',
#  '14,999',
#  '5,299',
#  '8,990',
#  '16,499',
#  '11,990',
#  '9,990',
#  '5,399',
#  '5,299',
#  '15,999',
#  '8,999',
#  '13,999',
#  '5,999',
#  '6,999',
#  '7,499',
# ...

# %%
for p in range(1,25):
    r1 = requests.get('https://www.amazon.in/s?k=smartphones&i=electronics&rh=n%3A976419031%2Cp_36%3A-2000000&dc&page=' + str(p), headers=headers)#, proxies=proxies)
    content1 = r.content

    soup1 = BeautifulSoup(content, 'html.parser')
    
    get_rating=soup.find_all('span',attrs={'class':'a-icon-alt'})
    for i in get_rating:
        rating.append(i.text.replace('\n',''))

# %%
rating
# Out:
# ['4 Stars & Up',
#  '3 Stars & Up',
#  '2 Stars & Up',
#  '1 Star & Up',
#  '4.2 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.2 out of 5 stars',
#  '3.4 out of 5 stars',
#  '4.2 out of 5 stars',
#  '3.9 out of 5 stars',
#  '2.8 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.0 out of 5 stars',
#  '3.9 out of 5 stars',
#  '3.4 out of 5 stars',
#  '4.2 out of 5 stars',
#  '5.0 out of 5 stars',
#  '3.4 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.3 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4 Stars & Up',
#  '3 Stars & Up',
#  '2 Stars & Up',
#  '1 Star & Up',
#  '4.2 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.2 out of 5 stars',
#  '3.4 out of 5 stars',
#  '4.2 out of 5 stars',
#  '3.9 out of 5 stars',
#  '2.8 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.0 out of 5 stars',
#  '3.9 out of 5 stars',
#  '3.4 out of 5 stars',
# ...

# %%
import re

# %%
for p in range(1,25):
    r1 = requests.get('https://www.amazon.in/s?k=smartphones&i=electronics&rh=n%3A976419031%2Cp_36%3A-2000000&dc&page=' + str(p), headers=headers)#, proxies=proxies)
    content1 = r.content

    soup1 = BeautifulSoup(content, 'html.parser')
    
    get_img_src=soup.find_all('img', {'src':re.compile('.jpg')})
#    classes_soup = BeautifulSoup(str(get_img_src))
#    for a in classes_soup.find_all('a', href=True):
#        image.append(a['href'])
    for i in get_img_src:
        image.append(i['src'].replace('\n',''))

# %%
image
# Out:
# ['https://images-eu.ssl-images-amazon.com/images/G/31/prime/Gateway/2020/June/gaming-swm._CB430661085_.jpg',
#  'https://m.media-amazon.com/images/I/71QLvGIAq5L._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71A9Vo1BatL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71dujTTJDZL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71AYb2AGHXL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71hDPUM7VPL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/81onqHVeECL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/41QsvcpKaZL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/716tvc8pVEL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71QLvGIAq5L._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71A9Vo1BatL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/81o1rDu5FZL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71AYb2AGHXL._AC_UY218_.jpg',
# ...

# %%
len(Name),len(price),len(rating),len(image)
# Out:
# (600, 600, 624, 624)

# %%
mobile_df=pd.DataFrame({})
mobile_df['Name']=Name[0:600]
mobile_df['Price']=price[0:600]
mobile_df['Ratings']=rating[0:600]
mobile_df['Image_Url']=image[0:600]
mobile_df
# Out:
#                                                   Name   Price  \
# 0    Samsung Galaxy M21 (Raven Black, 6GB RAM, 128G...  15,999
# 1            Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)   8,999
# 2    Samsung Galaxy M21 (Midnight Blue, 4GB RAM, 64...  13,999
# 3    Samsung Galaxy M01 Core (Black, 2GB RAM, 32GB ...   5,999
# 4       Redmi 9A (Nature Green, 2GB Ram, 32GB Storage)   6,999
# ..                                                 ...     ...
# 595  Samsung Galaxy M31 (Space Black, 6GB RAM, 128G...  16,499
# 596  Oppo A31 (Mystery Black, 6GB RAM, 128GB Storag...  11,990
# 597  Vivo U10 (Thunder Black,5000 mAH 18W Fast Char...   9,990
# 598  I KALL K400 Smartphone (6 Inch, 4GB, 64GB, Dua...   5,399
# 599  I KALL K900 Smartphone (5.5 Inch, 4GB, 64GB, 4...   5,299
#
#                 Ratings                                          Image_Url
# 0          4 Stars & Up  https://images-eu.ssl-images-amazon.com/images...
# ...
